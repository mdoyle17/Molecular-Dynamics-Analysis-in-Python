# %% [markdown]
# # Load up generic water dataframe template

# %%
import pandas as pd
import numpy as np
import math
from IPython.display import clear_output
import timeit

def distance(p0, p1):
    return math.sqrt((p0[0] - p1[0])**2 + (p0[1] - p1[1])**2 +(p0[2] - p1[2])**2  )
# !pwd
finalgro=pd.read_pickle('MD_files/WaterIDs.pkl')
# Out:
# /Users/yyk_lab/Downloads/MD_scripts/MVP scripts/MD_Paper_Scripts

# %% [markdown]
# ## Load up first reference pdb

# %%
gro_path =  '/Users/yyk_lab/Downloads/0F.pdb_fittedto55all.pdb'
colspecs_pdb = [(0, 6), (6, 11), (12, 16), (16, 17), (17, 20), (21, 22), (22, 26),
            (26, 27), (30, 38), (38, 46), (46, 54), (54, 60), (60, 66), (76, 78),
            (78, 80)]


names_pdb = ['ATOM', 'serial', 'name', 'altloc', 'resname', 'chainid', 'resseq',
         'icode', 'x', 'y', 'z', 'occupancy', 'tempfactor', 'element', 'charge']

reference = pd.read_fwf(gro_path, names=names_pdb, colspecs=colspecs_pdb, skiprows=2)

finalgro=reference[reference['resname']=='OOO']

finalgro.to_pickle('xtal_waters_refposition.pkl')
finalgro
# Out:
#          ATOM   serial name altloc resname chainid  resseq  icode       x  \
# 16554  HETATM  16547.0    O    NaN     OOO       G     1.0    NaN  65.040
# 16555  HETATM  16548.0    O    NaN     OOO       G     2.0    NaN  19.655
# 16556  HETATM  16549.0    O    NaN     OOO       G     3.0    NaN  41.234
# 16557  HETATM  16550.0    O    NaN     OOO       G     4.0    NaN  34.385
# 16558  HETATM  16551.0    O    NaN     OOO       G     5.0    NaN  96.070
# ...       ...      ...  ...    ...     ...     ...     ...    ...     ...
# 43126  HETATM  43099.0    O    NaN     OOO       g   136.0    NaN  57.162
# 43127  HETATM  43100.0    O    NaN     OOO       g   137.0    NaN  57.999
# 43128  HETATM  43101.0    O    NaN     OOO       g   138.0    NaN  49.000
# 43129  HETATM  43102.0    O    NaN     OOO       g   141.0    NaN  32.509
# 43130  HETATM  43103.0    O    NaN     OOO       g   142.0    NaN  32.409
#
#             y       z  occupancy  tempfactor element charge
# 16554  58.188  50.009       1.00       24.85       O    NaN
# 16555  54.694  51.414       1.00       35.38       O    NaN
# 16556  28.788  37.875       1.00       24.88       O    NaN
# 16557  54.734  27.038       1.00       28.43       O    NaN
# 16558  66.291  58.316       1.00       36.18       O    NaN
# ...       ...     ...        ...         ...     ...    ...
# 43126 -11.375  30.860       1.00       25.35       O    NaN
# 43127  -9.217  28.423       1.00       25.65       O    NaN
# 43128 -11.404  28.794       1.00       26.49       O    NaN
# 43129  -7.885  43.087       1.00       35.09       O    NaN
# 43130  -3.650  45.296       0.95       32.73       O    NaN
#
# [197 rows x 15 columns]

# %% [markdown]
# ## Next, load up average Ox density positions. These correspond to average oxygen positions over entire relevant trajectory.
# ## Then, replace the positions in dataframe above with the AVERAGE density from oxygen density map. This is final reference position.

# %%
colspecs_pdb = [(0, 6), (6, 11), (12, 16), (16, 17), (17, 20), (21, 22), (22, 26),
            (26, 27), (30, 38), (38, 46), (46, 54), (54, 60), (60, 66), (76, 78),
            (78, 80)]


names_pdb = ['ATOM', 'serial', 'name', 'altloc', 'resname', 'chainid', 'resseq',
         'icode', 'x', 'y', 'z', 'occupancy', 'tempfactor', 'element', 'charge']


pdb_path = '/Users/yyk_lab/Downloads/peaks_p212121_55ns_OW.pdb'
pdb = pd.read_fwf(pdb_path, names=names_pdb, colspecs=colspecs_pdb,skiprows=4)
pdb
# Out:
#        ATOM   serial name  altloc resname chainid  resseq  icode        x  \
# 0      ATOM  14260.0    O     NaN     HOH       X     1.0    NaN   58.575
# 1      ATOM   3951.0    O     NaN     HOH       X     2.0    NaN   -2.923
# 2      ATOM  13740.0    O     NaN     HOH       X     3.0    NaN   55.858
# 3      ATOM   3951.0    O     NaN     HOH       X     4.0    NaN  114.640
# 4      ATOM  14487.0    O     NaN     HOH       X     5.0    NaN   60.187
# ...     ...      ...  ...     ...     ...     ...     ...    ...      ...
# 27498  ATOM   1647.0    O     NaN     HOH       Z  7501.0    NaN  -16.874
# 27499  ATOM  11418.0    O     NaN     HOH       Z  7502.0    NaN   42.050
# 27500  ATOM    142.0    O     NaN     HOH       Z  7503.0    NaN   91.656
# 27501  ATOM    142.0    O     NaN     HOH       Z  7504.0    NaN  -25.962
# 27502   END      NaN  NaN     NaN     NaN     NaN     NaN    NaN      NaN
#
#             y       z  occupancy  tempfactor element  charge
# 0     -27.597   3.925      12.27       12.27       O     NaN
# 1      70.720  36.879      12.18       12.18       O     NaN
# 2      40.721 -36.879      12.18       12.18       O     NaN
# 3      70.720  36.879      12.18       12.18       O     NaN
# 4     -29.503   2.414      12.09       12.09       O     NaN
# ...       ...     ...        ...         ...     ...     ...
# 27498  21.792   3.417       2.03        2.03       O     NaN
# 27499  24.404  84.761       2.03        2.03       O     NaN
# 27500  10.138  79.238       2.03        2.03       O     NaN
# 27501  10.138  79.238       2.03        2.03       O     NaN
# 27502     NaN     NaN        NaN         NaN     NaN     NaN
#
# [27503 rows x 15 columns]

# %% [markdown]
# ## Now, I am looping through my water dataframe and finding the average OX peak which corresponds most closely with each chain G water. I will then update positions in the dataframe accordingly so that the final Ox position is an average

# %%
dist = 1.5  #0.5 Angstrom was too small tbh. Assume I can find a peak within 1.5 Angstrom of each chain G water
for i, row in finalgro.iterrows():
     ###Water of choice,
    point1= [float(finalgro.loc[i,'x']),float(finalgro.loc[i,'y']),float(finalgro.loc[i,'z'])] 
    print('Water ID= %d' %finalgro.loc[i,'resseq'] )
    finalgro.loc[i,'OW_ID'] = 0 
    for q,raw in pdb.iterrows():
        point2= [pdb.loc[q,'x'],pdb.loc[q,'y'],pdb.loc[q,'z']] 
        if (distance(point1,point2) < dist) :
            print(distance(point1,point2))
            print("Peak ID = %d " %pdb.loc[q,'resseq'])
            print('******')
            #replace positions 
            finalgro.loc[i,'x'] = pdb.loc[q,'x']
            finalgro.loc[i,'y'] = pdb.loc[q,'y']
            finalgro.loc[i,'z'] = pdb.loc[q,'z']
            finalgro.loc[i,'OW_ID'] = pdb.loc[q,'resseq'] 
           
            break
# Out:
# Water ID= 1
# 0.6755397841726224
# Peak ID = 394
# ******
# Water ID= 2
# 0.5292872566007967
# Peak ID = 160
# ******
# Water ID= 3
# 0.4845430837397211
# Peak ID = 193
# ******
# Water ID= 4
# 0.3404159220718107
# Peak ID = 351
# ******
# Water ID= 5
# /Users/yyk_lab/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:376: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/yyk_lab/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# 0.5890967662447193
# Peak ID = 608
# ******
# Water ID= 6
# 0.8871240048606421
# Peak ID = 1659
# ******
# Water ID= 7
# 0.6247751595574204
# Peak ID = 22
# ******
# Water ID= 19
# 0.25908685802255405
# Peak ID = 432
# ******
# Water ID= 20
# 0.10570714261581877
# Peak ID = 2430
# ******
# Water ID= 21
# 0.5151883150848885
# Peak ID = 255
# ******
# Water ID= 22
# 0.6851240763540548
# Peak ID = 500
# ******
# Water ID= 23
# 0.40037232671602324
# Peak ID = 804
# ******
# Water ID= 24
# 0.36195579840637865
# Peak ID = 5115
# ******
# Water ID= 25
# 0.6095440919244458
# Peak ID = 4383
# ******
# Water ID= 26
# 0.2867158872472902
# Peak ID = 80
# ******
# Water ID= 27
# 0.5459203238568727
# Peak ID = 3387
# ******
# Water ID= 28
# 1.0812834965909712
# Peak ID = 2932
# ******
# Water ID= 29
# 0.4002424265367149
# Peak ID = 3304
# ******
# Water ID= 30
# 0.7501746463324506
# Peak ID = 2547
# ******
# Water ID= 31
# 0.42860004666356044
# Peak ID = 349
# ******
# Water ID= 32
# 0.21906620004007735
# Peak ID = 3045
# ******
# Water ID= 33
# 0.4374048467952982
# Peak ID = 2378
# ******
# Water ID= 34
# 0.2442805763870689
# Peak ID = 1590
# ******
# Water ID= 35
# 0.4972916649211024
# Peak ID = 1769
# ******
# Water ID= 36
# 0.16606324096560673
# Peak ID = 1784
# ******
# Water ID= 37
# 0.7997212014195951
# Peak ID = 2758
# ******
# Water ID= 38
# 0.4964967270788437
# Peak ID = 2277
# ******
# Water ID= 39
# 0.5742412385052145
# Peak ID = 736
# ******
# Water ID= 40
# 0.6989420576843224
# Peak ID = 1726
# ******
# Water ID= 41
# 0.6100319663755319
# Peak ID = 4208
# ******
# Water ID= 42
# 0.5383771911959102
# Peak ID = 378
# ******
# Water ID= 43
# 0.7038899061643059
# Peak ID = 5306
# ******
# Water ID= 44
# 0.22009316209278063
# Peak ID = 2281
# ******
# Water ID= 45
# 0.5913332393836763
# Peak ID = 5091
# ******
# Water ID= 46
# 0.6088834042737628
# Peak ID = 2905
# ******
# Water ID= 47
# 0.268253611345697
# Peak ID = 1782
# ******
# Water ID= 48
# 0.1991632496220138
# Peak ID = 975
# ******
# Water ID= 49
# 0.30796266007424533
# Peak ID = 1338
# ******
# Water ID= 50
# Water ID= 51
# 1.0484283475755494
# Peak ID = 2750
# ******
# Water ID= 52
# 0.803483042758221
# Peak ID = 3812
# ******
# Water ID= 53
# Water ID= 54
# 0.6851466996198756
# Peak ID = 3092
# ******
# Water ID= 55
# 0.3303059188086167
# Peak ID = 932
# ******
# Water ID= 56
# 0.3954465829919447
# Peak ID = 454
# ******
# Water ID= 57
# 0.3376433029100409
# 1.3435810358887903
# Peak ID = 5764
# ******
# Water ID= 136
# 0.4127396273681533
# Peak ID = 745
# ******
# Water ID= 137
# 0.8335358420608021
# Peak ID = 1940
# ******
# Water ID= 140
# 0.18425254408013067
# Peak ID = 461
# ******
# Water ID= 142
# 0.2482800837763717
# Peak ID = 1706
# ******
# Water ID= 143
# 0.4588725313199734
# Peak ID = 2042
# ******
# Water ID= 144
# 0.46765051053110424
# Peak ID = 1899
# ******
# Water ID= 1
# 0.8651416069060622
# Peak ID = 982
# ******
# Water ID= 2
# 0.7314991455907532
# Peak ID = 325
# ******
# Water ID= 3
# 0.5313040560733417
# Peak ID = 54
# ******
# Water ID= 4
# 0.45696498771787675
# Peak ID = 38
# ******
# Water ID= 5
# 0.4534148211075573
# Peak ID = 2309
# ******
# Water ID= 6
# 0.9543510884365352
# Peak ID = 471
# ******
# Water ID= 7
# 0.31002580537755503
# Peak ID = 181
# ******
# Water ID= 19
# 0.2742608247635786
# Peak ID = 583
# ******
# Water ID= 20
# 0.4193113401757729
# Peak ID = 1881
# ******
# Water ID= 21
# 0.521372227875629
# Peak ID = 285
# ******
# Water ID= 22
# 0.33525810952160373
# Peak ID = 144
# ******
# Water ID= 23
# 0.21935359582190875
# Peak ID = 999
# ******
# Water ID= 24
# 0.7277533922971403
# Peak ID = 3469
# ******
# Water ID= 25
# 0.41087467675679407
# Peak ID = 7723
# ******
# Water ID= 26
# 0.4422431457919955
# Peak ID = 773
# ******
# Water ID= 27
# 1.002087321544385
# Peak ID = 1573
# ******
# Water ID= 28
# 0.7929779315970918
# Peak ID = 1313
# ******
# Water ID= 29
# 0.3375011111092809
# Peak ID = 43
# ******
# Water ID= 30
# 1.1302743029902071
# Peak ID = 204
# ******
# Water ID= 31
# 0.5098911648577564
# Peak ID = 377
# ******
# Water ID= 32
# 0.6292606773031342
# Peak ID = 1676
# ******
# Water ID= 33
# 0.5110714235799149
# Peak ID = 1884
# ******
# Water ID= 34
# 0.5069339207431266
# Peak ID = 1326
# ******
# Water ID= 35
# 0.1270787157631074
# Peak ID = 1461
# ******
# Water ID= 36
# 0.21533694527414354
# Peak ID = 1280
# ******
# Water ID= 37
# 0.1118972743189085
# Peak ID = 4557
# ******
# Water ID= 38
# 0.509954899966661
# Peak ID = 3135
# ******
# Water ID= 40
# 1.2064219825583413
# Peak ID = 1757
# ******
# Water ID= 41
# 0.921270861364892
# Peak ID = 4953
# ******
# Water ID= 42
# 0.06429618962271576
# Peak ID = 396
# ******
# Water ID= 43
# 0.6107675498911203
# Peak ID = 3459
# ******
# Water ID= 44
# 0.09648315915225641
# Peak ID = 3024
# ******
# Water ID= 45
# 0.7350380942509024
# Peak ID = 5968
# ******
# Water ID= 46
# 0.5156326211557983
# Peak ID = 3088
# ******
# Water ID= 47
# 0.24920272871699953
# Peak ID = 633
# ******
# Water ID= 48
# 0.23461457755220497
# Peak ID = 1020
# ******
# Water ID= 49
# 0.17586642658563403
# Peak ID = 1380
# ******
# Water ID= 50
# 1.43395013860315
# Peak ID = 4466
# ******
# 0.3216084576002322
# Peak ID = 1574
# ******
# Water ID= 132
# 0.4914224252107315
# Peak ID = 252
# ******
# Water ID= 133
# 0.24948547051882722
# Peak ID = 4944
# ******
# Water ID= 134
# 0.8412044935686012
# Peak ID = 6425
# ******
# Water ID= 135
# 0.6657567123206546
# Peak ID = 165
# ******
# Water ID= 136
# 0.3567309910843176
# Peak ID = 810
# ******
# Water ID= 137
# 0.45206304870006625
# Peak ID = 1777
# ******
# Water ID= 138
# 0.2164901845350022
# Peak ID = 241
# ******
# Water ID= 141
# 0.45233947428895255
# Peak ID = 2121
# ******
# Water ID= 142
# 0.43626368173388064
# Peak ID = 3653
# ******

# %% [markdown]
# ## Final dataframe with Ox as reference point

# %%
finalgro.to_pickle('Waters_Odensity_xtalposition.pkl')
finalgro
# Out:
#          ATOM   serial name altloc resname chainid  resseq  icode       x  \
# 16554  HETATM  16547.0    O    NaN     OOO       G     1.0    NaN  64.825
# 16555  HETATM  16548.0    O    NaN     OOO       G     2.0    NaN  19.738
# 16556  HETATM  16549.0    O    NaN     OOO       G     3.0    NaN  41.664
# 16557  HETATM  16550.0    O    NaN     OOO       G     4.0    NaN  34.062
# 16558  HETATM  16551.0    O    NaN     OOO       G     5.0    NaN  95.647
# ...       ...      ...  ...    ...     ...     ...     ...    ...     ...
# 43126  HETATM  43099.0    O    NaN     OOO       g   136.0    NaN  56.941
# 43127  HETATM  43100.0    O    NaN     OOO       g   137.0    NaN  57.924
# 43128  HETATM  43101.0    O    NaN     OOO       g   138.0    NaN  49.066
# 43129  HETATM  43102.0    O    NaN     OOO       g   141.0    NaN  32.420
# 43130  HETATM  43103.0    O    NaN     OOO       g   142.0    NaN  32.083
#
#             y       z  occupancy  tempfactor element charge   OW_ID
# 16554  58.165  49.369       1.00       24.85       O    NaN   394.0
# 16555  55.144  51.148       1.00       35.38       O    NaN   160.0
# 16556  28.977  37.756       1.00       24.88       O    NaN   193.0
# 16557  54.839  27.061       1.00       28.43       O    NaN   351.0
# 16558  66.150  57.931       1.00       36.18       O    NaN   608.0
# ...       ...     ...        ...         ...     ...    ...     ...
# 43126 -11.479  31.120       1.00       25.35       O    NaN   810.0
# 43127  -9.661  28.463       1.00       25.65       O    NaN  1777.0
# 43128 -11.468  28.990       1.00       26.49       O    NaN   241.0
# 43129  -7.948  43.526       1.00       35.09       O    NaN  2121.0
# 43130  -3.895  45.141       0.95       32.73       O    NaN  3653.0
#
# [197 rows x 16 columns]

# %% [markdown]
# ## Now I need to attempt to match up oxygens with average HW positions  for each chain G

# %%
pdb_path = '/Users/yyk_lab/Downloads/peaks_p212121_55ns_HW_2sig.pdb'
pdb_1 = pd.read_fwf(pdb_path, names=names_pdb, colspecs=colspecs_pdb,skiprows=4)
pdb_1
# Out:
#        ATOM  serial name  altloc resname chainid  resseq  icode        x  \
# 0      ATOM   983.0    O     NaN     HOH       X     1.0    NaN  -17.581
# 1      ATOM  7226.0    O     NaN     HOH       X     2.0    NaN   41.201
# 2      ATOM   983.0    O     NaN     HOH       X     3.0    NaN   99.982
# 3      ATOM  1760.0    O     NaN     HOH       X     4.0    NaN   -9.646
# 4      ATOM  8103.0    O     NaN     HOH       X     5.0    NaN   49.135
# ...     ...     ...  ...     ...     ...     ...     ...    ...      ...
# 17748  ATOM   117.0    O     NaN     HOH       Y  7750.0    NaN  -25.962
# 17749  ATOM  2705.0    O     NaN     HOH       Y  7751.0    NaN  116.732
# 17750  ATOM  9108.0    O     NaN     HOH       Y  7752.0    NaN   57.950
# 17751  ATOM  2705.0    O     NaN     HOH       Y  7753.0    NaN   -0.831
# 17752   END     NaN  NaN     NaN     NaN     NaN     NaN    NaN      NaN
#
#             y       z  occupancy  tempfactor element  charge
# 0      82.748 -37.676       7.24        7.24       O     NaN
# 1      28.693  37.676       7.24        7.24       O     NaN
# 2      82.748 -37.676       7.24        7.24       O     NaN
# 3     -66.919 -10.668       7.15        7.15       O     NaN
# 4     -44.522  10.668       7.15        7.15       O     NaN
# ...       ...     ...        ...         ...     ...     ...
# 17748 -61.502  89.601       2.02        2.02       O     NaN
# 17749 -39.657 -31.840       2.02        2.02       O     NaN
# 17750 -71.784  31.840       2.02        2.02       O     NaN
# 17751 -39.657 -31.840       2.02        2.02       O     NaN
# 17752     NaN     NaN        NaN         NaN     NaN     NaN
#
# [17753 rows x 15 columns]

# %%
hw1_df=[]
dist = 1.4
for f, rof in finalgro.iterrows():
    point1= [float(finalgro.loc[f,'x']),float(finalgro.loc[f,'y']),float(finalgro.loc[f,'z'])]  #average Ox pos
    print('Water ID= %d' %finalgro.loc[f,'resseq'] )
    finalgro.loc[f,'HW1_ID'] = 0
    finalgro.loc[f,'HW1_x'] = 0
    finalgro.loc[f,'HW1_y'] = 0
    finalgro.loc[f,'HW1_z'] = 0
    
    for g,rog in pdb_1.iterrows():
        point2= [pdb_1.loc[g,'x'],pdb_1.loc[g,'y'],pdb_1.loc[g,'z']] 
        if (distance(point1,point2) < dist) :
            print("HW1 Peak ID = %d " %pdb_1.loc[g,'resseq'])
            finalgro.loc[f,'HW1_ID'] = pdb_1.loc[g,'resseq']
            finalgro.loc[f,'HW1_x'] = pdb_1.loc[g,'x']
            finalgro.loc[f,'HW1_y'] = pdb_1.loc[g,'y']
            finalgro.loc[f,'HW1_z'] = pdb_1.loc[g,'z']
            break
# Out:
# Water ID= 1
# HW1 Peak ID = 676
# Water ID= 2
# HW1 Peak ID = 306
# Water ID= 3
# HW1 Peak ID = 2
# Water ID= 4
# HW1 Peak ID = 348
# Water ID= 5
# HW1 Peak ID = 489
# Water ID= 6
# HW1 Peak ID = 1008
# Water ID= 7
# HW1 Peak ID = 274
# Water ID= 19
# HW1 Peak ID = 425
# Water ID= 20
# HW1 Peak ID = 1857
# Water ID= 21
# HW1 Peak ID = 462
# Water ID= 22
# HW1 Peak ID = 1018
# Water ID= 23
# HW1 Peak ID = 1248
# Water ID= 24
# HW1 Peak ID = 4957
# Water ID= 25
# Water ID= 26
# HW1 Peak ID = 4542
# Water ID= 27
# HW1 Peak ID = 3849
# Water ID= 28
# HW1 Peak ID = 1971
# Water ID= 29
# HW1 Peak ID = 3184
# Water ID= 127
# HW1 Peak ID = 1587
# Water ID= 129
# HW1 Peak ID = 3133
# Water ID= 130
# HW1 Peak ID = 1074
# Water ID= 131
# HW1 Peak ID = 1680
# Water ID= 132
# HW1 Peak ID = 6272
# Water ID= 133
# HW1 Peak ID = 2217
# Water ID= 134
# HW1 Peak ID = 5784
# Water ID= 135
# HW1 Peak ID = 4072
# Water ID= 136
# HW1 Peak ID = 315
# Water ID= 137
# HW1 Peak ID = 2308
# Water ID= 140
# HW1 Peak ID = 947
# Water ID= 142
# HW1 Peak ID = 889
# Water ID= 143
# HW1 Peak ID = 1147
# Water ID= 144
# HW1 Peak ID = 3185
# Water ID= 1
# HW1 Peak ID = 1880
# Water ID= 2
# HW1 Peak ID = 1698
# Water ID= 3
# HW1 Peak ID = 264
# Water ID= 4
# HW1 Peak ID = 20
# Water ID= 5
# HW1 Peak ID = 1644
# Water ID= 6
# HW1 Peak ID = 282
# Water ID= 7
# HW1 Peak ID = 673
# Water ID= 19
# HW1 Peak ID = 398
# Water ID= 20
# HW1 Peak ID = 2479
# Water ID= 21
# HW1 Peak ID = 28
# Water ID= 22
# HW1 Peak ID = 510
# Water ID= 23
# HW1 Peak ID = 3259
# Water ID= 24
# HW1 Peak ID = 6078
# Water ID= 25
# HW1 Peak ID = 3867
# Water ID= 26
# HW1 Peak ID = 1131
# Water ID= 27
# HW1 Peak ID = 2430
# Water ID= 28
# HW1 Peak ID = 1269
# Water ID= 29
# HW1 Peak ID = 616
# Water ID= 30
# HW1 Peak ID = 174
# Water ID= 31
# HW1 Peak ID = 780
# Water ID= 32
# HW1 Peak ID = 2423
# Water ID= 33
# HW1 Peak ID = 2042
# Water ID= 34
# HW1 Peak ID = 925
# Water ID= 35
# HW1 Peak ID = 351
# Water ID= 36
# HW1 Peak ID = 1130
# Water ID= 37
# HW1 Peak ID = 3059
# Water ID= 38
# HW1 Peak ID = 1342
# Water ID= 40
# HW1 Peak ID = 3080
# Water ID= 41
# HW1 Peak ID = 6333
# Water ID= 42
# HW1 Peak ID = 125
# Water ID= 43
# HW1 Peak ID = 1266
# Water ID= 44
# HW1 Peak ID = 3495
# Water ID= 45
# HW1 Peak ID = 4626
# Water ID= 46
# HW1 Peak ID = 1874
# Water ID= 47
# HW1 Peak ID = 1053
# Water ID= 48
# HW1 Peak ID = 401
# Water ID= 49
# HW1 Peak ID = 1054
# Water ID= 50
# HW1 Peak ID = 4192
# Water ID= 51
# HW1 Peak ID = 820
# Water ID= 52
# HW1 Peak ID = 4310
# Water ID= 53
# Water ID= 54
# HW1 Peak ID = 463
# Water ID= 55
# HW1 Peak ID = 1045
# Water ID= 56
# HW1 Peak ID = 334
# Water ID= 57
# HW1 Peak ID = 1760
# Water ID= 58
# HW1 Peak ID = 321
# Water ID= 59
# HW1 Peak ID = 161
# Water ID= 60
# Water ID= 61
# HW1 Peak ID = 874
# Water ID= 62
# HW1 Peak ID = 131
# Water ID= 63
# HW1 Peak ID = 2159
# Water ID= 64
# HW1 Peak ID = 1487
# Water ID= 65
# HW1 Peak ID = 2366
# Water ID= 66
# HW1 Peak ID = 1298
# Water ID= 67
# HW1 Peak ID = 1313
# Water ID= 68
# HW1 Peak ID = 2079
# Water ID= 69
# HW1 Peak ID = 1888
# Water ID= 70
# HW1 Peak ID = 5338
# Water ID= 71
# HW1 Peak ID = 2994
# Water ID= 72
# HW1 Peak ID = 3629
# Water ID= 73
# HW1 Peak ID = 1944
# Water ID= 74
# HW1 Peak ID = 405
# Water ID= 75
# HW1 Peak ID = 665
# Water ID= 76
# Water ID= 77
# Water ID= 78
# HW1 Peak ID = 3139
# Water ID= 101
# HW1 Peak ID = 977
# Water ID= 102
# HW1 Peak ID = 2270
# Water ID= 110
# HW1 Peak ID = 2299
# Water ID= 111
# HW1 Peak ID = 331
# Water ID= 112
# HW1 Peak ID = 268
# Water ID= 113
# HW1 Peak ID = 3834
# Water ID= 114
# HW1 Peak ID = 1551
# Water ID= 115
# HW1 Peak ID = 581
# Water ID= 116
# HW1 Peak ID = 3725
# Water ID= 117
# HW1 Peak ID = 3355
# Water ID= 118
# HW1 Peak ID = 1075
# Water ID= 119
# HW1 Peak ID = 2086
# Water ID= 120
# Water ID= 149
# Water ID= 121
# HW1 Peak ID = 3876
# Water ID= 122
# HW1 Peak ID = 946
# Water ID= 125
# HW1 Peak ID = 1371
# Water ID= 126
# HW1 Peak ID = 2130
# Water ID= 127
# HW1 Peak ID = 818
# Water ID= 129
# HW1 Peak ID = 3355
# Water ID= 130
# HW1 Peak ID = 854
# Water ID= 131
# HW1 Peak ID = 2323
# Water ID= 132
# Water ID= 133
# HW1 Peak ID = 1967
# Water ID= 134
# HW1 Peak ID = 6462
# Water ID= 135
# Water ID= 136
# HW1 Peak ID = 696
# Water ID= 137
# HW1 Peak ID = 1939
# Water ID= 138
# HW1 Peak ID = 831
# Water ID= 141
# HW1 Peak ID = 2584
# Water ID= 142
# HW1 Peak ID = 3001

# %% [markdown]
# ## Almost done... Finding H bond partners

# %%
for p,rop in finalgro.iterrows():
    dist_lowest = 3.5 #will be replaced by shortest H bond distance 
    point1= [float(finalgro.loc[p,'x']),float(finalgro.loc[p,'y']),float(finalgro.loc[p,'z'])]  #Ox
    for q,roq in finalgro.iterrows(): 
        point2 =[float(finalgro.loc[q,'HW1_x']),float(finalgro.loc[q,'HW1_y']),float(finalgro.loc[q,'HW1_z'])] 
        if (distance(point1,point2) < dist_lowest) and (p!=q) :
            dist_lowest = distance(point1,point2)
            finalgro.loc[p,'waterID_h1_partner']= finalgro.loc[q,'resseq']
            finalgro.loc[p,'h1_partner_id']= finalgro.loc[q,'HW1_ID']
            finalgro.loc[p,'ow_h1_partner_dist'] = distance(point1,point2)

            point4 =[float(finalgro.loc[q,'x']),float(finalgro.loc[q,'y']),float(finalgro.loc[q,'z'])] #O
            finalgro.loc[p,'o_o_dist_h1_partner'] = distance(point1,point4)

# %%
finalgro.to_pickle('hbond_analysis.pkl')
finalgro

finalgro=pd.read_pickle('hbond_analysis.pkl')
finalgro
finalgro[5:20]
finalgro = finalgro.replace('NaN', 0)
finalgro = finalgro.replace(np.nan, 0)

# %%
finalgro
# Out:
#          ATOM   serial name  altloc resname chainid  resseq  icode       x  \
# 16554  HETATM  16547.0    O     0.0     OOO       G     1.0    0.0  64.825
# 16555  HETATM  16548.0    O     0.0     OOO       G     2.0    0.0  19.738
# 16556  HETATM  16549.0    O     0.0     OOO       G     3.0    0.0  41.664
# 16557  HETATM  16550.0    O     0.0     OOO       G     4.0    0.0  34.062
# 16558  HETATM  16551.0    O     0.0     OOO       G     5.0    0.0  95.647
# ...       ...      ...  ...     ...     ...     ...     ...    ...     ...
# 43126  HETATM  43099.0    O     0.0     OOO       g   136.0    0.0  56.941
# 43127  HETATM  43100.0    O     0.0     OOO       g   137.0    0.0  57.924
# 43128  HETATM  43101.0    O     0.0     OOO       g   138.0    0.0  49.066
# 43129  HETATM  43102.0    O     0.0     OOO       g   141.0    0.0  32.420
# 43130  HETATM  43103.0    O     0.0     OOO       g   142.0    0.0  32.083
#
#             y  ...  charge   OW_ID  HW1_ID   HW1_x   HW1_y   HW1_z  \
# 16554  58.165  ...     0.0   394.0   676.0  65.107  58.127  49.867
# 16555  55.144  ...     0.0   160.0   306.0  19.579  54.611  51.275
# 16556  28.977  ...     0.0   193.0     2.0  41.201  28.693  37.676
# 16557  54.839  ...     0.0   351.0   348.0  34.710  54.797  26.999
# 16558  66.150  ...     0.0   608.0   489.0  96.013  66.015  58.416
# ...       ...  ...     ...     ...     ...     ...     ...     ...
# 43126 -11.479  ...     0.0   810.0   696.0  56.381 -11.370  31.185
# 43127  -9.661  ...     0.0  1777.0  1939.0  57.686  -9.381  28.012
# 43128 -11.468  ...     0.0   241.0   831.0  48.865 -11.324  29.542
# 43129  -7.948  ...     0.0  2121.0  2584.0  32.955  -7.638  43.788
# 43130  -3.895  ...     0.0  3653.0  3001.0  31.861  -4.642  44.978
#
#        waterID_h1_partner  h1_partner_id  ow_h1_partner_dist  \
# 16554                 0.0            0.0            0.000000
# 16555                 0.0            0.0            0.000000
# 16556                 0.0            0.0            0.000000
# 16557                 0.0            0.0            0.000000
# 16558                 0.0            0.0            0.000000
# ...                   ...            ...                 ...
# 43126               134.0         6462.0            3.127173
# 43127               134.0         6462.0            3.209666
# 43128                69.0         1888.0            3.076048
# 43129               126.0         2130.0            2.262565
# 43130               126.0         2130.0            3.327649
#
#        o_o_dist_h1_partner
# 16554             0.000000
# 16555             0.000000
# 16556             0.000000
# 16557             0.000000
# 16558             0.000000
# ...                    ...
# 43126             2.827404
# 43127             3.297637
# 43128             3.456769
# 43129             2.928332
# 43130             3.458341
#
# [197 rows x 24 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.ticker as plticker
plt.rc('font', family='serif')


chain = 'g'
chan = 'O4'

fig = plt.figure(figsize=(18, 5))
ax1 = fig.add_subplot(111)
ax1.set_xlabel('Water ID (acceptor)',fontsize=16)
ax2 = ax1.twiny()
ax2.set_xlabel('Water ID (donor)', fontsize=16 )
ax2.set_title('%s Channel, chain %s' %(chan,chain) ,fontsize=20, pad=25)
ax2.xaxis.labelpad=10.0
ax1.set_ylabel(r'Distance $(\AA$)', fontsize=16)
id1=72
id2=78
ticklabels2=[]
ticklabels1=[]
strength = []
if chan == 'O1':
    st =  [26,27,28,29,30,32,33,34,35,36,37,38,39, 76,77, 101, 102, 151,31,103,104,105,106,107]
elif chan == 'Cl':
    st = [21,22,23,24,25,40,41,42, 61, 62, 117, 119, 121, 122, 125, 145, 150, 59, 60, 66, 67, 68, 69, 70]
else:
    st=[19,20,48,49,50,51,52,53, 71, 72, 73]

if chain == 'G':
    offset = 0
else:
    offset = 100
haystack= set(finalgro['resseq'][offset:500])
o1_b=([i for i, e in enumerate(haystack) if e in st])
o1_b= [x+offset for x in o1_b]
z=0
prev1=0
prev2 = 0 
for p in o1_b:
   
    if (finalgro['waterID_h1_partner'].iloc[p] ==0 ):
        continue
    if finalgro['OW_ID'].iloc[p]==0:
        continue
    if (finalgro['resseq'].iloc[p] == prev1 and finalgro['waterID_h1_partner'].iloc[p] == prev2) :
        continue
    if finalgro['HW1_ID'].iloc[p]==0 or finalgro['HW1_ID'].iloc[p]==0:
        continue
   
    ax1.scatter(z,finalgro['ow_h1_partner_dist'].iloc[p],s=100, color='blue',edgecolor='black',label ='O-H1 distance')
    ax1.scatter(z,finalgro['o_o_dist_h1_partner'].iloc[p] ,s=100,color='orange',edgecolor='black', label ='O-O distance')
    ax2.plot(z, 1,color='white') 
    ticklabels1.append(finalgro['resseq'].iloc[p])
    ticklabels2.append(finalgro['waterID_h1_partner'].iloc[p])

    z=z+1

ax1.set_xticks(np.arange(0,len(ticklabels2),1))
ax2.set_xticks(np.arange(0,len(ticklabels2),1))
ax2.set_xticklabels(np.array(ticklabels2).astype(int))
ax1.set_xticklabels(np.array(ticklabels1).astype(int))

ax1.fill_between(np.arange(0,len(ticklabels2),1), 2.5, 3.2, color='green',alpha=0.1,)
ax1.fill_between(np.arange(0,len(ticklabels2),1), 2.2, 2.5, color='yellow',alpha=0.1, label='strong, mostly covalent')

ax1.fill_between(np.arange(0,len(ticklabels2),1), 0, 2.2, color='red',alpha=0.1, label='very strong')

    
a = mpatches.Patch(color='green', alpha = 0.1,  label='moderate, mostly electrostatic')
b= mpatches.Patch(color='yellow', alpha = 0.1,  label='strong, mostly covalent')
c= mpatches.Patch(color='red', alpha = 0.1,  label='very strong')
d= mpatches.Patch(color='blue',  label='o-h distance')
e= mpatches.Patch(color='orange',  label='o-o distance')
ax2.legend(handles=[a,b,c], bbox_to_anchor=(1.29, 0.87),prop={"size":13})
colors = ["b", "orange"]
texts = ["o-h distance", "o-o distance"]
patches = [ plt.plot([],[], marker="o", ms=10, ls="", mec=None, color=colors[i], 
            label="{:s}".format(texts[i]) )[0]  for i in range(len(texts)) ]
ax1.legend(handles=patches, bbox_to_anchor=(1, 1), 
           loc='upper left', ncol=2,  numpoints=1 ,prop={"size":13})
ax1.set_ylim(1.3,4)
ax1.set_ylim(1.3,4)
loc = plticker.MultipleLocator(base=1.0) # this locator puts ticks at regular intervals
# plt.tight_layout()
plt.savefig('%s_hbond.png' %chan,  bbox_inches='tight',dpi=100)
