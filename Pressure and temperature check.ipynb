# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rc('font', family='serif', size=18)
plt.rc('xtick', labelsize='medium')
plt.rc('ytick', labelsize='medium')
def movingaverage(interval, window_size):
    window= np.ones(int(window_size))/float(window_size)
    return np.convolve(interval, window, 'same')
plt.rc('font', family='serif', size=18)
plt.rc('xtick', labelsize='medium')
plt.rc('ytick', labelsize='medium')

# %% [markdown]
# # Load up pressure .xvg file, plot with moving average

# %%
x,y = np.loadtxt("MD_files/pressure_5ns.xvg",comments="@",unpack=True, skiprows=13)
y_av = movingaverage(y, 10)
time_in_ns = (len(x) *2 -2)/1000

fig = plt.figure(figsize=(7, 5))
ax = fig.add_subplot(1, 1, 1)

ax.plot(x,y,'o',label='Data')
ax.set_xlabel('Time (ps)')
ax.set_ylabel('Pressure (bar)')
ax.plot(x,y_av,label='Moving Average')

plt.title('Pressure Analysis (%d ns)\n Average= %0.2f bar' %(time_in_ns, np.mean(y)))
plt.legend()
plt.tight_layout()
plt.savefig('Pressure_5ns.jpg', dpi=300)

a=np.mean(y)
b= np.std(y)
c = max(y)
d = min(y)

print('Full run stats: mean = %d; stdev = %0.02f, max= %d, min = %d' %(a, b, c, d))
# Out:
# Full run stats: mean = -95; stdev = 338.59, max= 992, min = -1126

# %% [markdown]
# # Load up temp .xvg file, and plot

# %%
x,y = np.loadtxt("MD_files/temp_5ns.xvg",comments="@",unpack=True, skiprows=13)
y_av = movingaverage(y, 10)

fig = plt.figure(figsize=(7, 5))
ax = fig.add_subplot(1, 1, 1)

ax.plot(x,y,'o',label='Data')
ax.set_xlabel('Time (ps)')
ax.set_ylabel('Temp (K)')


plt.title('Temperature Analysis (%d ns)\n Average= %0.2f K' %(time_in_ns, np.mean(y)))
plt.legend()
plt.tight_layout()
plt.savefig('Temperature_5ns.jpg', dpi=300)

a=np.mean(y)
b= np.std(y)
c = max(y)
d = min(y)

print('Full run stats: mean = %d; stdev = %0.02f, max= %d, min = %d' %(a, b, c, d))
# Out:
# Full run stats: mean = 297; stdev = 0.38, max= 299, min = 296
